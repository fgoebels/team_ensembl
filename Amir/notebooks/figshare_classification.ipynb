# %%
import re
import numpy as np
import pandas as pd
from scipy import sparse
from datetime import datetime

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from wordcloud import WordCloud

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC

from sklearn.base import BaseEstimator

from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import train_test_split
from sklearn.model_selection import ShuffleSplit

from sklearn.metrics import log_loss, confusion_matrix

from sklearn.feature_selection import SelectKBest, chi2, f_classif, mutual_info_classif, SelectPercentile

from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

from sklearn.externals import joblib

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
# the docker container is too small to run the gridsearch
# %env JOBLIB_TEMP_FOLDER=/tmp
# Out:
# env: JOBLIB_TEMP_FOLDER=/tmp

# %% [markdown]
# ## read data

# %%
annotations = pd.read_csv('../input/toxicity_annotations.tsv', sep='\t')
comments = pd.read_csv('../input/toxicity_annotated_comments.tsv', sep='\t')

# %%
comments = comments.rename(columns={'rev_Id': 'rev_id'})

# %%
annotations.shape
# Out:
# (1598289, 4)

# %%
comments.shape
# Out:
# (159686, 7)

# %%
avg_annotations = annotations.groupby('rev_id').agg({'toxicity_score': ['mean', 'std']}).reset_index()

# %%
plt.hist(avg_annotations['toxicity_score']['std'])
# Out:
# (array([  3.58200000e+03,   1.16000000e+02,   2.32870000e+04,
#           7.02880000e+04,   3.90690000e+04,   1.65910000e+04,
#           5.56100000e+03,   9.84000000e+02,   1.92000000e+02,
#           1.60000000e+01]),
#  array([ 0.        ,  0.15491933,  0.30983867,  0.464758  ,  0.61967734,
#          0.77459667,  0.929516  ,  1.08443534,  1.23935467,  1.394274  ,
#          1.54919334]),
#  <a list of 10 Patch objects>)

# %%
data = avg_annotations.merge(comments, on='rev_id', how='inner')
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/reshape/merge.py:551: UserWarning: merging between different levels can give an unintended result (2 levels on the left, 1 on the right)
#   warnings.warn(msg, UserWarning)

# %%
data
# Out:
#              rev_id   (rev_id, )  (toxicity_score, mean)  (toxicity_score, std)                                            comment  year  logged_in       ns   sample  split
# 0            2232.0       2232.0                0.400000               0.699206  This:NEWLINE_TOKEN:One can make an analogy in ...  2002       True  article   random  train
# 1            4216.0       4216.0                0.500000               0.707107  `NEWLINE_TOKENNEWLINE_TOKEN:Clarification for ...  2002       True     user   random  train
# 2            8953.0       8953.0                0.100000               0.316228                          Elected or Electoral? JHK  2002      False  article   random   test
# 3           26547.0      26547.0                0.600000               0.843274  `This is such a fun entry.   DevotchkaNEWLINE_...  2002       True  article   random  train
# 4           28959.0      28959.0                0.200000               0.788811  Please relate the ozone hole to increases in c...  2002       True  article   random   test
# 5           35367.0      35367.0                0.200000               0.632456  `:In an interpreted language your source code ...  2002       True  article   random    dev
# 6           37330.0      37330.0                0.100000               0.875595  `NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENI fixe...  2002       True  article   random  train
# 7           37346.0      37346.0                0.200000               0.632456  `If they are ``indisputable`` then why does th...  2002       True  article   random  train
# 8           37675.0      37675.0                0.300000               0.948683  `-NEWLINE_TOKENThis is not ``creative``.  Thos...  2002      False  article   random    dev
# 9           44377.0      44377.0                0.800000               0.632456  `NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENThe co...  2002       True  article   random  train
# 10          52473.0      52473.0                0.600000               0.516398  `NEWLINE_TOKENNEWLINE_TOKENCan anyone provide ...  2002       True  article   random    dev
# 11          66667.0      66667.0                0.200000               0.421637  `just quick notes, since i don't have the time...  2002       True  article   random  train
# 12          91460.0      91460.0                0.200000               0.632456  `The actual idea behind time-out is to get the...  2002       True  article   random  train
# 13         109914.0     109914.0                0.300000               0.674949  Done. This entry is lond, I'll see about chopp...  2002       True  article   random    dev
# 14         113226.0     113226.0                0.400000               0.516398  Note to Eclecticology: Hum, you just brought t...  2002       True  article   random    dev
# 15         114890.0     114890.0                0.300000               0.674949  `NEWLINE_TOKEN NEWLINE_TOKENNEWLINE_TOKENNEWLI...  2002       True     user   random  train
# 16         116583.0     116583.0                0.666667               0.500000  NEWLINE_TOKENNEWLINE_TOKEN7.11.02 1610 - Mav: ...  2002       True     user   random    dev
# 17         120509.0     120509.0                0.200000               0.421637         A new classification table is at Hominid.   2002       True  article   random    dev
# 18         132491.0     132491.0                0.100000               0.567646  `]NEWLINE_TOKENNEWLINE_TOKEN:: When I'm angry,...  2002       True  article   random  train
# 19         138074.0     138074.0                0.500000               0.527046  `NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENNEWLIN...  2002       True  article   random   test
# 20         139768.0     139768.0                0.400000               0.699206  `NEWLINE_TOKENNEWLINE_TOKEN===Announcement===N...  2002       True  article   random  train
# 21         143728.0     143728.0                0.900000               0.567646  NEWLINE_TOKEN:: You have a valid point,, thank...  2002       True  article   random  train
# 22         146770.0     146770.0                0.300000               0.483046  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENNEWLINE...  2002       True  article   random  train
# 23         153941.0     153941.0                0.500000               0.707107  `I do not understand this sentence: ``Several ...  2002      False  article   random  train
# 24         162213.0     162213.0                0.900000               0.567646  NEWLINE_TOKENNEWLINE_TOKEN:: Thanks for your h...  2002       True     user   random    dev
# 25         175279.0     175279.0                0.600000               0.516398  NEWLINE_TOKENNEWLINE_TOKENI didn't, I simply m...  2002       True     user   random    dev
# 26         177450.0     177450.0                0.500000               0.527046  `NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENNEWLIN...  2002       True     user   random  train
# 27         179630.0     179630.0                0.300000               0.483046  `NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKEN: At t...  2002       True  article   random  train
# 28         188130.0     188130.0                0.800000               0.421637  NEWLINE_TOKENNEWLINE_TOKENNo, it is not the sa...  2002       True  article   random    dev
# 29         189361.0     189361.0                0.600000               0.516398  `NEWLINE_TOKEN-NEWLINE_TOKENBe lenient on Topo...  2002       True     user   random    dev
# 30         195355.0     195355.0                0.600000               0.516398  NEWLINE_TOKEN::::That's reasonable enough; I j...  2002       True     user   random    dev
# 31         198261.0     198261.0                0.900000               0.737865  NEWLINE_TOKENNEWLINE_TOKENI think it is 1861. ...  2002       True  article   random  train
# 32         200354.0     200354.0                0.600000               0.699206  NEWLINE_TOKENNEWLINE_TOKENok i'll come back. B...  2002       True     user   random  train
# 33         200664.0     200664.0                0.400000               0.516398  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKEN NEWLIN...  2002       True     user   random   test
# 34         201712.0     201712.0                0.400000               0.516398  NEWLINE_TOKENNEWLINE_TOKENHello there, welcome...  2002       True     user   random  train
# 35         207166.0     207166.0                0.600000               0.699206  `NEWLINE_TOKENNEWLINE_TOKEN: To attempt to bri...  2002       True  article   random  train
# 36         207582.0     207582.0                0.400000               0.516398  NEWLINE_TOKENNEWLINE_TOKEN::: On the fringes o...  2002       True  article   random    dev
# 37         213105.0     213105.0                0.300000               0.483046  `NEWLINE_TOKENNEWLINE_TOKEN: I should do that ...  2002       True     user   random   test
# 38         218624.0     218624.0                0.900000               0.567646  `I've heard it said that Charles Darwin did no...  2002       True  article   random  train
# 39         225277.0     225277.0                0.400000               0.699206  NEWLINE_TOKENNEWLINE_TOKENThanks for reverting...  2002       True     user   random  train
# 40         225986.0     225986.0                0.400000               0.516398  Or, they could change the school schedules to ...  2002       True  article   random  train
# 41         227181.0     227181.0                0.454545               0.687552  NEWLINE_TOKENNEWLINE_TOKENWell, Ayn Rand certa...  2002       True  article   random  train
# 42         250290.0     250290.0                0.400000               0.699206  Ed, I am tired!  Anyway, I certainly did not m...  2002       True     user   random  train
# 43         258303.0     258303.0                0.800000               0.788811  `Well, I am not trying to pick a fight ) but I...  2002       True  article   random   test
# 44         270660.0     270660.0                0.700000               0.674949  NEWLINE_TOKENNEWLINE_TOKENI must admit, that f...  2001       True  article   random    dev
# 45         279420.0     279420.0                0.400000               0.699206  Article says:NEWLINE_TOKENNEWLINE_TOKEN:A cant...  2002       True  article   random    dev
# 46         281382.0     281382.0                0.300000               0.483046  `NEWLINE_TOKENNEWLINE_TOKENSpan occurs not as ...  2001       True  article   random  train
# 47         285223.0     285223.0                0.200000               0.918937  NEWLINE_TOKENNEWLINE_TOKENOh, never mind.  I m...  2001       True  article   random  train
# 48         297866.0     297866.0                0.200000               0.632456  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENNEWLINE...  2001       True  article   random  train
# 49         309756.0     309756.0                0.600000               0.516398  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENCompute...  2002       True  article   random    dev
# 50         313929.0     313929.0                0.600000               0.699206  NEWLINE_TOKEN:(1) I really do not want to caus...  2002       True  article   random    dev
# 51         315967.0     315967.0                0.500000               0.527046  `NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKEN: Just...  2002       True     user   random    dev
# 52         325217.0     325217.0                0.500000               0.527046  Take a look at this article , to see that, eve...  2002       True  article   random    dev
# 53         344571.0     344571.0                0.200000               0.421637  NEWLINE_TOKENNEWLINE_TOKEN-NEWLINE_TOKENNEWLIN...  2002      False  article   random  train
# 54         360594.0     360594.0                0.400000               0.843274  NEWLINE_TOKENNEWLINE_TOKEN::I disagree. I woul...  2002      False     user  blocked  train
# 55         369632.0     369632.0                0.300000               0.674949  `:Chalk one up for Ed!  Robert MerkelNEWLINE_T...  2002       True  article   random  train
# 56         372885.0     372885.0                0.700000               0.674949  `NEWLINE_TOKEN:Thanks, but I don't have that l...  2002       True     user   random   test
# 57         377054.0     377054.0                0.400000               0.699206  NEWLINE_TOKENNEWLINE_TOKEN:::I don't know wher...  2002      False     user  blocked    dev
# 58         421759.0     421759.0                0.400000               0.516398  NEWLINE_TOKENNEWLINE_TOKENremember...the UN ha...  2002       True  article   random  train
# 59         424060.0     424060.0                0.600000               0.516398  NEWLINE_TOKENNEWLINE_TOKENOff-the-cuff remarks...  2002       True  article   random    dev
# 60         427355.0     427355.0                0.200000               0.421637  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENwhats s...  2002       True     user   random   test
# 61         436779.0     436779.0                1.000000               0.666667  `NEWLINE_TOKENNEWLINE_TOKEN: Ed, we all have o...  2002       True     user   random    dev
# 62         440929.0     440929.0                0.500000               0.527046  .NEWLINE_TOKENNEWLINE_TOKEN:And this is an exc...  2002       True  article   random  train
# 63         442563.0     442563.0                0.600000               0.516398  `::::I double checked...sure enough, the delet...  2002      False  article   random  train
# 64         450405.0     450405.0                0.700000               0.674949  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENNEWLINE...  2002       True  article   random  train
# 65         452612.0     452612.0                0.400000               0.699206  Oh, I'm sure I could find a copy around somewh...  2002       True  article   random   test
# 66         460704.0     460704.0                0.000000               0.774597  Similary, they were not doing that badly in th...  2002       True  article   random  train
# 67         478459.0     478459.0                0.200000               0.421637   Actually, yes, that's what I'm saying. The pr...  2002       True  article   random    dev
# 68         482033.0     482033.0                0.300000               0.823273  `::Yes, I think we've achieved understanding! ...  2002       True  article   random  train
# 69         527004.0     527004.0                0.000000               0.000000  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENNEWLINE...  2002       True     user   random   test
# 70         529575.0     529575.0                0.100000               0.567646  NEWLINE_TOKENNEWLINE_TOKENDarling Zoe: Why did...  2002      False     user   random  train
# 71         535667.0     535667.0                0.300000               0.483046  `NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENI addd...  2002       True     user   random  train
# 72         546477.0     546477.0                0.400000               0.516398  To see the problem with the sentence, you don'...  2002       True  article   random  train
# 73         570342.0     570342.0                0.000000               0.471405  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENNEWLINE...  2003       True     user   random  train
# 74         576228.0     576228.0                0.300000               0.483046  `Is the paragraph under ``He asserted the foll...  2003       True  article   random   test
# 75         577214.0     577214.0                0.700000               0.483046  NEWLINE_TOKENNEWLINE_TOKEN: I'm guessing it me...  2003       True  article   random  train
# 76         581297.0     581297.0                0.000000               0.471405  `no mention of ``To Love Somebody`` from 1967?...  2003       True  article   random  train
# 77         587384.0     587384.0                0.700000               0.674949  NEWLINE_TOKENNEWLINE_TOKENDavid, I have a coup...  2003       True     user   random   test
# 78         587393.0     587393.0                0.600000               0.516398  NEWLINE_TOKENNEWLINE_TOKENnot many film buff s...  2003       True  article   random  train
# 79         593987.0     593987.0                0.000000               0.942809  There's nothing about Benito Mussolini or the ...  2003       True  article   random   test
# 80         594502.0     594502.0                0.700000               0.483046  Basically, I agree with Ortolan. In any case, ...  2003       True  article   random  train
# 81         595963.0     595963.0                0.400000               0.516398  NEWLINE_TOKENNEWLINE_TOKENIt's not official, o...  2003       True  article   random    dev
# 82         597212.0     597212.0               -0.600000               0.843274  `NEWLINE_TOKENNEWLINE_TOKENAfter the wasted bi...  2003      False  article   random   test
# 83         598296.0     598296.0                0.300000               0.483046  Is this original work, or derived from another...  2002       True  article   random   test
# 84         603474.0     603474.0                0.000000               0.000000  `:Here I cannot answer your questions.  I did ...  2003       True  article   random  train
# 85         607274.0     607274.0                0.400000               0.516398  NEWLINE_TOKEN::Fair enough.  I'm doing this an...  2002       True  article   random  train
# 86         608166.0     608166.0               -0.100000               0.567646  1. I don't think unreadable is that far off be...  2003       True  article   random  train
# 87         612650.0     612650.0                0.800000               0.632456  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENFor pho...  2003       True     user   random  train
# 88         615528.0     615528.0                0.500000               0.527046  The pressure difference above and below the wi...  2003      False  article   random  train
# 89         616393.0     616393.0                0.400000               0.516398  Welcome to userland 168!  19:58 Jan 23, 2003 (...  2003       True     user   random  train
# 90         617026.0     617026.0                0.300000               0.483046  NEWLINE_TOKENNEWLINE_TOKEN: All sources seem t...  2003       True  article   random    dev
# 91         620797.0     620797.0                0.300000               0.483046  The sale of the Danish West Indies to the US i...  2003      False  article   random  train
# 92         622082.0     622082.0                0.600000               0.516398  NEWLINE_TOKENNEWLINE_TOKEN::Well, it's a quest...  2003       True  article   random  train
# 93         623718.0     623718.0                0.000000               0.471405  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENNEWLINE...  2003       True  article   random    dev
# 94         630630.0     630630.0                0.300000               0.674949  On second thought, why not instead provide a n...  2003       True     user   random   test
# 95         639419.0     639419.0                0.700000               0.823273  NEWLINE_TOKENNEWLINE_TOKENI wish to apoligize ...  2003       True     user   random  train
# 96         655852.0     655852.0                0.200000               0.421637  `NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENNEWLIN...  2003       True     user   random  train
# 97         659391.0     659391.0                0.200000               0.788811  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENNEWLINE...  2003       True  article   random    dev
# 98         661509.0     661509.0                0.200000               0.632456  MarcusAurelius]]NEWLINE_TOKENNEWLINE_TOKENNEWL...  2003      False     user  blocked  train
# 99         672149.0     672149.0                0.300000               0.674949  `NEWLINE_TOKENNEWLINE_TOKENIt should be ``bail...  2003       True  article   random   test
# 100        672191.0     672191.0                0.400000               0.699206  NEWLINE_TOKENNEWLINE_TOKENNow, who donates a n...  2003       True  article   random  train
# 101        672331.0     672331.0                0.636364               0.504525  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENThe new...  2003       True  article   random   test
# 102        672976.0     672976.0                0.700000               0.483046  Thanks Lament for the restore.  I don't dare t...  2003      False     user   random  train
# 103        673906.0     673906.0                0.200000               0.632456  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENThe who...  2003       True  article   random    dev
# 104        682829.0     682829.0               -0.400000               0.966092  NEWLINE_TOKENNEWLINE_TOKENYou'd think neonazis...  2003       True     user   random  train
# 105        684743.0     684743.0                0.600000               0.516398  NEWLINE_TOKENNEWLINE_TOKEN:I don't think I und...  2003       True     user   random   test
# 106        685917.0     685917.0                0.600000               0.516398  `NEWLINE_TOKENNEWLINE_TOKEN:Let me recap your ...  2003       True  article   random  train
# 107        694234.0     694234.0                0.400000               0.516398  `NEWLINE_TOKENNEWLINE_TOKEN::Likewise used GIM...  2003       True     user   random  train
# 108        697935.0     697935.0                0.600000               0.516398  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENTannin,...  2003       True  article   random  train
# 109        705539.0     705539.0                0.800000               0.632456  `NEWLINE_TOKENNEWLINE_TOKEN::Excellent! It's a...  2003       True     user   random  train
# 110        707010.0     707010.0                0.200000               0.632456  The link to SGC Belfry Ted Nude-Gent is dead. ...  2003      False  article  blocked  train
# 111        712490.0     712490.0                0.100000               0.567646  NEWLINE_TOKENNEWLINE_TOKENJust one question th...  2003       True  article   random   test
# 112        718907.0     718907.0                0.800000               0.632456  NEWLINE_TOKENNEWLINE_TOKENActually Mary II was...  2003       True     user   random  train
# 113        723811.0     723811.0                0.500000               0.527046  NEWLINE_TOKENNEWLINE_TOKEN-NEWLINE_TOKENNEWLIN...  2003       True  article   random    dev
# 114        724915.0     724915.0                0.400000               0.516398  `Where's the 24 defendants figure coming from?...  2003      False  article  blocked   test
# 115        727773.0     727773.0                0.500000               0.527046  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENI under...  2003       True  article   random   test
# 116        728052.0     728052.0                0.800000               0.421637  NEWLINE_TOKENThank you for the deletion log li...  2003       True     user   random  train
# 117        732895.0     732895.0                0.600000               0.699206  NEWLINE_TOKENNEWLINE_TOKENLooks like be have a...  2003       True     user   random  train
# 118        739998.0     739998.0                0.300000               0.483046  NEWLINE_TOKENNEWLINE_TOKEN:There probably othe...  2003       True  article   random    dev
# 119        740297.0     740297.0                0.600000               0.516398  `I would like to propose name convension about...  2003       True  article   random  train
# 120        743907.0     743907.0                0.800000               0.421637  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENNEWLINE...  2003       True  article   random  train
# 121        745260.0     745260.0                0.300000               0.483046  `NEWLINE_TOKENNEWLINE_TOKENIt would list only ...  2003       True  article   random  train
# 122        749900.0     749900.0                0.100000               0.567646  NEWLINE_TOKENNEWLINE_TOKENThe Macedonian ORIGI...  2003      False  article   random    dev
# 123        757206.0     757206.0                0.400000               0.699206  NEWLINE_TOKENNEWLINE_TOKENBigFatBuddha: Do you...  2003       True  article   random  train
# 124        761965.0     761965.0                0.400000               0.699206  NEWLINE_TOKENNEWLINE_TOKENNice work on this ar...  2003       True  article   random  train
# 125        773674.0     773674.0                0.200000               0.788811  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENNEWLINE...  2003       True  article   random  train
# 126        778895.0     778895.0                0.600000               0.516398  `Actually, it is not known commonly as ``Revel...  2003      False  article   random  train
# 127        782604.0     782604.0               -0.100000               0.567646  NEWLINE_TOKENNEWLINE_TOKENI second that. I am ...  2003       True     user   random  train
# 128        783481.0     783481.0               -0.400000               0.516398  NEWLINE_TOKENNEWLINE_TOKEN::If I pick enough h...  2003       True     user   random  train
# 129        785036.0     785036.0                0.300000               0.674949  `NEWLINE_TOKEN-NEWLINE_TOKEN``Part of the US p...  2003       True  article   random   test
# 130        786272.0     786272.0                0.800000               0.421637  That's what I was moving them to, but hey. I'm...  2003       True     user   random  train
# 131        787425.0     787425.0                0.100000               0.875595  NEWLINE_TOKEN-NEWLINE_TOKENHi Mav. I see 172 h...  2003       True     user   random  train
# 132        789508.0     789508.0                0.000000               0.666667  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENNEWLINE...  2003       True     user   random  train
# 133        790462.0     790462.0                0.400000               0.843274   Sorry, you send this message to the wrong user.   2003       True     user   random  train
# 134        793426.0     793426.0                0.500000               0.527046  NEWLINE_TOKENNEWLINE_TOKENSome of them were qu...  2003       True  article   random    dev
# 135        808576.0     808576.0                0.000000               0.000000  NEWLINE_TOKENNEWLINE_TOKENIn fact, I've just d...  2003       True     user   random    dev
# 136        813717.0     813717.0                0.400000               0.516398  NEWLINE_TOKENNEWLINE_TOKENIs it correct to say...  2003      False  article   random    dev
# 137        817668.0     817668.0                0.200000               0.421637  NEWLINE_TOKENNEWLINE_TOKEN::OK. I'll try to fi...  2003       True     user   random  train
# 138        818559.0     818559.0                0.100000               0.316228                   Should it really redirect here?   2003       True  article   random    dev
# 139        820504.0     820504.0                0.300000               0.674949  `NEWLINE_TOKENNEWLINE_TOKENWhat were originall...  2003       True  article   random  train
# 140        825305.0     825305.0                0.700000               0.483046  oh the classic SM/DF response. That was only o...  2003       True     user   random   test
# 141        847569.0     847569.0                0.800000               0.788811  NEWLINE_TOKENNEWLINE_TOKENHi, you have made ve...  2003       True     user   random  train
# 142        856388.0     856388.0                0.200000               0.632456  `NEWLINE_TOKENNEWLINE_TOKEN:The Protocols isn'...  2003       True  article   random    dev
# 143        857940.0     857940.0                0.400000               0.699206  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENNEWLINE...  2003       True     user   random    dev
# 144        872596.0     872596.0                0.300000               0.483046  NEWLINE_TOKENNEWLINE_TOKENNo, but the balance ...  2003       True  article   random  train
# 145        876815.0     876815.0                0.400000               0.699206  NEWLINE_TOKENNEWLINE_TOKEN:And the coolest thi...  2003       True     user   random  train
# 146        877539.0     877539.0                0.300000               0.483046  NEWLINE_TOKENNEWLINE_TOKENI agree that as far ...  2003       True  article   random  train
# 147        878062.0     878062.0                0.200000               0.421637  `NEWLINE_TOKENNEWLINE_TOKEN:So how long will i...  2003       True     user   random    dev
# 148        890523.0     890523.0                0.600000               0.516398  Please notice that I am keepeng track and docu...  2003       True     user   random   test
# 149        906335.0     906335.0                0.400000               0.516398  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENNEWLINE...  2003       True  article   random  train
# 150        907008.0     907008.0                0.200000               0.632456  NEWLINE_TOKENNEWLINE_TOKENWhat do you mean? Co...  2003       True  article   random  train
# 151        907842.0     907842.0                0.600000               0.516398  NEWLINE_TOKENNEWLINE_TOKEN:I believe it's beca...  2003       True  article   random   test
# 152        927125.0     927125.0                0.300000               0.483046  NEWLINE_TOKEN: Apologies, have just read the h...  2003       True  article   random  train
# 153        932889.0     932889.0                0.400000               0.516398  NEWLINE_TOKENNEWLINE_TOKENDid you know that if...  2003       True     user   random  train
# 154        939951.0     939951.0                0.400000               0.516398  `NEWLINE_TOKENNEWLINE_TOKENIf you were to go t...  2003       True  article   random    dev
# 155        950508.0     950508.0                0.400000               0.516398   NEWLINE_TOKENBut anyway, Great idea adding th...  2003       True     user   random    dev
# 156        950556.0     950556.0                1.000000               0.471405  Hello Zeizmic, welcome to the 'pedia! I hope y...  2003       True     user   random  train
# 157        962237.0     962237.0                0.300000               0.483046  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENYep - m...  2003       True     user   random  train
# 158        967782.0     967782.0                0.300000               0.483046  It was said a comunist state which is not true...  2002      False  article   random  train
# 159        967899.0     967899.0                0.200000               0.421637  I think this page should include a reference t...  2003      False  article  blocked  train
# 160        981476.0     981476.0                0.000000               0.666667  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENHow cou...  2003       True     user   random   test
# 161        986199.0     986199.0                0.400000               0.843274  `NEWLINE_TOKEN-NEWLINE_TOKENHallo Tony!NEWLINE...  2003       True     user   random  train
# 162        986363.0     986363.0                0.000000               0.000000                             16:13 1 Jun 2003 (UTC)  2003       True  article   random  train
# 163        987262.0     987262.0                1.000000               0.471405  NEWLINE_TOKENNEWLINE_TOKENThanks for your asis...  2003       True     user   random  train
# 164        988775.0     988775.0                0.500000               0.707107  NEWLINE_TOKENNEWLINE_TOKENQuit fooling around ...  2003       True     user   random  train
# 165        997691.0     997691.0                0.200000               0.421637  `NEWLINE_TOKENNEWLINE_TOKEN: I meant ``prematu...  2003       True  article   random   test
# 166       1004237.0    1004237.0                0.700000               0.674949  NEWLINE_TOKENNEWLINE_TOKEN: I agree that we sh...  2003       True  article   random  train
# 167       1017722.0    1017722.0                0.300000               0.483046  NEWLINE_TOKENNEWLINE_TOKEN:Hmmm... well I expe...  2003       True     user   random   test
# 168       1018446.0    1018446.0                0.500000               0.527046  `NEWLINE_TOKENNEWLINE_TOKEN:No, it shouldn't b...  2003       True  article   random  train
# 169       1019723.0    1019723.0                0.100000               0.316228  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENNEWLINE...  2003       True     user   random    dev
# 170       1027666.0    1027666.0                0.300000               0.674949  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENNEWLINE...  2003       True     user   random  train
# 171       1030882.0    1030882.0                0.300000               0.483046  NEWLINE_TOKEN-NEWLINE_TOKENCreated and copyrig...  2003       True     user   random  train
# 172       1040549.0    1040549.0                0.900000               0.567646  `::Ah. I hope you're happier with the current ...  2003       True     user   random  train
# 173       1041178.0    1041178.0                0.600000               0.516398  `NEWLINE_TOKENO, please excuse my misspelling ...  2003       True     user   random   test
# 174       1050542.0    1050542.0                0.600000               0.516398  `NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENHello ...  2003       True     user   random    dev
# 175       1064037.0    1064037.0                0.100000               0.737865  NEWLINE_TOKENNEWLINE_TOKENI repeat: You cannot...  2003       True     user   random  train
# 176       1068694.0    1068694.0                0.600000               0.516398  NEWLINE_TOKENI was just looking at your intere...  2003      False     user   random   test
# 177       1068991.0    1068991.0                0.272727               0.467099  NEWLINE_TOKENNEWLINE_TOKENThis article needs t...  2003       True  article   random  train
# 178       1074095.0    1074095.0                0.600000               0.516398  `:: Hmm, Thinking about it, getting involved i...  2003      False  article   random    dev
# 179       1078251.0    1078251.0                0.300000               0.483046  `NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENNEWLIN...  2003       True  article   random  train
# 180       1079734.0    1079734.0                0.400000               0.516398  NEWLINE_TOKENNEWLINE_TOKEN:  they weren't. I'l...  2003       True     user   random   test
# 181       1081209.0    1081209.0                0.400000               0.516398  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENHi Eric...  2003       True     user   random  train
# 182       1083879.0    1083879.0                1.000000               0.471405  Hello there Harris7, welcome to Wikipedia! I h...  2003       True     user   random    dev
# 183       1093056.0    1093056.0                0.600000               0.516398   NEWLINE_TOKEN-NEWLINE_TOKENOk, that is a good...  2002       True  article   random  train
# 184       1104240.0    1104240.0                0.400000               0.516398  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENIn answ...  2003       True     user   random  train
# 185       1104309.0    1104309.0                0.200000               0.421637  `::there were some ``unacceptable`` problems r...  2003       True  article   random  train
# 186       1105194.0    1105194.0                0.400000               0.516398  `NEWLINE_TOKENNEWLINE_TOKEN:This has been a lo...  2003       True     user   random  train
# 187       1111203.0    1111203.0                0.600000               0.516398  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENNEWLINE...  2003       True     user   random  train
# 188       1115300.0    1115300.0                0.500000               0.527046  NEWLINE_TOKENNEWLINE_TOKEN:I find these naviga...  2003       True  article   random  train
# 189       1120127.0    1120127.0                0.600000               0.516398  NEWLINE_TOKENNEWLINE_TOKEN-NEWLINE_TOKEN:The p...  2003       True  article   random   test
# 190       1133583.0    1133583.0                0.000000               0.816497  `NEWLINE_TOKENNEWLINE_TOKENPlease note that yo...  2003      False     user  blocked    dev
# 191       1135780.0    1135780.0                0.400000               0.516398  NEWLINE_TOKENNEWLINE_TOKENRe Efghi's complete ...  2003       True  article   random    dev
# 192       1139051.0    1139051.0                0.300000               0.674949  NEWLINE_TOKENNEWLINE_TOKENI confess to having ...  2003       True     user   random  train
# 193       1141254.0    1141254.0                0.200000               0.421637  NEWLINE_TOKENNEWLINE_TOKENOh, now I see.NEWLIN...  2003       True     user   random  train
# 194       1146485.0    1146485.0                0.300000               0.674949  NEWLINE_TOKEN:::I'm all for pruning down the W...  2003       True  article   random  train
# 195       1171026.0    1171026.0                0.200000               0.788811  I'd be interested to know why this page discus...  2003       True  article   random    dev
# 196       1182442.0    1182442.0                0.500000               0.707107  `NEWLINE_TOKENNEWLINE_TOKENIt's so frustrating...  2003       True     user   random  train
# 197       1185061.0    1185061.0                0.300000               0.674949  NEWLINE_TOKENNEWLINE_TOKENWould inclusion of a...  2003       True  article   random  train
# 198       1212179.0    1212179.0                0.200000               0.421637  NEWLINE_TOKENNEWLINE_TOKEN:I'll edit and add s...  2003       True  article   random   test
# 199       1220248.0    1220248.0                0.400000               0.699206  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENThanks ...  2003       True     user   random  train
# 200       1222396.0    1222396.0                0.300000               0.483046  NEWLINE_TOKENNEWLINE_TOKEN:::That's my guess. ...  2003       True  article   random  train
# 201       1225776.0    1225776.0                0.600000               0.516398  Hallo Mister Kev Beach - please move the conte...  2003       True     user   random    dev
# 202       1229123.0    1229123.0                0.600000               0.699206  `NEWLINE_TOKENNEWLINE_TOKEN== LanguageWikibook...  2003       True     user   random  train
# 203       1238726.0    1238726.0                0.400000               0.699206  NEWLINE_TOKEN:If everyone follow this rule, I ...  2003       True     user   random  train
# 204       1239681.0    1239681.0                0.600000               0.516398  That is a 100% correct line, not nonsense. Nat...  2003       True     user   random  train
# 205       1244245.0    1244245.0                0.400000               0.516398  NEWLINE_TOKENNEWLINE_TOKEN: At that speed I'm ...  2003       True     user   random  train
# 206       1244775.0    1244775.0                0.600000               0.699206  NEWLINE_TOKENNEWLINE_TOKENI've prepared your w...  2003       True     user   random  train
# 207       1245501.0    1245501.0                0.400000               0.699206  NEWLINE_TOKENNEWLINE_TOKEN:I was with you unti...  2003       True  article   random   test
# 208       1249995.0    1249995.0                0.600000               0.699206  NEWLINE_TOKENNEWLINE_TOKEN:::::::Firstly, don'...  2003       True  article   random  train
# 209       1254306.0    1254306.0                0.000000               0.666667  `NEWLINE_TOKENNEWLINE_TOKEN: Perhaps. But it i...  2003       True  article   random  train
# 210       1257618.0    1257618.0                0.400000               0.516398  NEWLINE_TOKENNEWLINE_TOKEN: I wasn't going to ...  2003       True  article   random  train
# 211       1266286.0    1266286.0               -0.500000               0.971825  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENNEWLINE...  2003       True     user   random   test
# 212       1274199.0    1274199.0                0.200000               0.632456  NEWLINE_TOKENNEWLINE_TOKEN:No need to apologiz...  2003       True     user   random   test
# 213       1284764.0    1284764.0                0.500000               0.527046  `NEWLINE_TOKENNEWLINE_TOKEN:The thing is, it d...  2003       True     user   random  train
# 214       1286353.0    1286353.0                0.300000               0.483046  NEWLINE_TOKENNEWLINE_TOKEN: It's not that you ...  2003       True     user   random  train
# 215       1290459.0    1290459.0                0.200000               0.632456  Well, you pretty much backed up what I was say...  2003       True     user   random    dev
# 216       1294384.0    1294384.0               -0.200000               1.135292  `** What exactly is ignorant and absurd about ...  2003       True     user   random   test
# 217       1305406.0    1305406.0               -0.100000               0.737865  NEWLINE_TOKENNEWLINE_TOKENHe's a repeat offend...  2003       True     user   random  train
# 218       1308838.0    1308838.0                0.300000               0.483046           to give you a citation of th title of it  2003       True  article   random  train
# 219       1310817.0    1310817.0                0.200000               0.421637  `NEWLINE_TOKENNEWLINE_TOKEN-NEWLINE_TOKENNEWLI...  2003       True     user   random  train
# 220       1311822.0    1311822.0                0.300000               0.674949  NEWLINE_TOKENNEWLINE_TOKENThis title is meanin...  2003       True  article   random  train
# 221       1314902.0    1314902.0                0.200000               1.135292  GOD BLESS OUR FREEDOM FIGHTING TROOPS DEFEATIN...  2003       True     user   random  train
# 222       1322268.0    1322268.0                0.300000               0.483046  NEWLINE_TOKENNEWLINE_TOKENIf I may ask, what i...  2003      False  article   random   test
# 223       1325310.0    1325310.0                0.300000               0.483046  You can post me messages here.NEWLINE_TOKENNEW...  2003      False     user   random    dev
# 224       1332551.0    1332551.0                0.400000               0.843274  NEWLINE_TOKENNEWLINE_TOKENMoved from the artic...  2003       True  article   random  train
# 225       1334050.0    1334050.0                0.400000               0.516398  I beg you pardon? Who is us and who is them? A...  2003       True  article   random  train
# 226       1334930.0    1334930.0                0.500000               0.527046  Please feel free to add anything you feel I've...  2003       True     user   random  train
# 227       1337346.0    1337346.0                0.100000               0.567646  `NEWLINE_TOKENNEWLINE_TOKENIt appears under a ...  2003       True  article   random    dev
# 228       1343592.0    1343592.0                0.500000               0.527046  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENNEWLINE...  2003       True  article   random  train
# 229       1347368.0    1347368.0                0.400000               0.699206  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKEN-NEWLIN...  2003       True  article   random  train
# 230       1354074.0    1354074.0                0.200000               0.918937   I think the article about the Balkan peninsul...  2003       True  article   random   test
# 231       1357291.0    1357291.0                0.700000               0.483046  `NEWLINE_TOKENNEWLINE_TOKEN::I now replaced ``...  2003       True  article   random  train
# 232       1360210.0    1360210.0                0.300000               0.483046  NEWLINE_TOKENNEWLINE_TOKENWe're supposed to be...  2003       True     user   random    dev
# 233       1378649.0    1378649.0                0.800000               0.632456  NEWLINE_TOKENNEWLINE_TOKENIn response to your ...  2003       True     user   random  train
# 234       1382722.0    1382722.0                0.400000               0.516398  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKEN:The re...  2003       True  article   random    dev
# 235       1391062.0    1391062.0                0.600000               0.516398  `NEWLINE_TOKENNEWLINE_TOKEN:One way of acheivi...  2003       True  article   random    dev
# 236       1419503.0    1419503.0                0.375000               0.744024  NEWLINE_TOKENNEWLINE_TOKEN-NEWLINE_TOKENNEWLIN...  2003       True     user   random  train
# 237       1433843.0    1433843.0                0.000000               0.000000        NEWLINE_TOKENNEWLINE_TOKEN:I replied on .    2003       True     user   random  train
# 238       1434512.0    1434512.0                0.600000               0.699206  `NEWLINE_TOKENNEWLINE_TOKEN:Freud's ideas are ...  2003       True  article   random  train
# 239       1438215.0    1438215.0                0.800000               0.632456  `NEWLINE_TOKENNEWLINE_TOKEN== Most respected d...  2003       True  article   random  train
# 240       1455567.0    1455567.0                0.200000               0.632456  NEWLINE_TOKENNEWLINE_TOKENp.s. for the record,...  2003       True  article   random  train
# 241       1466040.0    1466040.0                0.500000               0.527046  Hi Qqq. Please note that pages in the User: na...  2003       True     user   random    dev
# 242       1477013.0    1477013.0                0.500000               0.527046  `__NOTOC__NEWLINE_TOKEN Greetings,NEWLINE_TOKE...  2003       True     user   random    dev
# 243       1485630.0    1485630.0                0.300000               0.483046  NEWLINE_TOKENNEWLINE_TOKEN:Many of the images ...  2003       True     user   random  train
# 244       1494812.0    1494812.0                0.700000               0.483046  NEWLINE_TOKENNEWLINE_TOKEN::military equipment...  2003      False  article   random  train
# 245       1502668.0    1502668.0               -1.250000               0.707107  BOOBS, BOOBS, BOOBS, BOOBS, BOOBS, BOOBS, BOOB...  2003       True     user  blocked   test
# 246       1510588.0    1510588.0                0.400000               0.516398              Article needs some work. Take a look.  2002      False  article   random  train
# 247       1519973.0    1519973.0                0.700000               0.483046  NEWLINE_TOKENNEWLINE_TOKEN::Lol. Glad to have ...  2003       True     user   random  train
# 248       1522602.0    1522602.0                0.400000               0.699206  NEWLINE_TOKENNEWLINE_TOKENAngela, you're right...  2003       True     user   random  train
# 249       1523535.0    1523535.0                0.500000               0.527046  NEWLINE_TOKENNEWLINE_TOKENI made a contributio...  2003       True  article   random   test
# ...             ...          ...                     ...                    ...                                                ...   ...        ...      ...      ...    ...
# 159436  698658195.0  698658195.0                0.300000               0.483046  `NEWLINE_TOKENNEWLINE_TOKEN== gurjars ==NEWLIN...  2016       True     user  blocked    dev
# 159437  698658829.0  698658829.0                0.600000               0.516398  NEWLINE_TOKENNEWLINE_TOKEN==January 2016==NEWL...  2016       True     user   random  train
# 159438  698661286.0  698661286.0                0.700000               0.483046  NEWLINE_TOKENNEWLINE_TOKEN== Tanisha Sharma ==...  2016       True     user   random    dev
# 159439  698682322.0  698682322.0                0.300000               0.483046  `NEWLINE_TOKEN::::::::Oppose (per numerous arg...  2016       True  article   random  train
# 159440  698687194.0  698687194.0                0.500000               0.527046  `NEWLINE_TOKEN:::They aren't as far as I can s...  2016       True     user   random  train
# 159441  698703430.0  698703430.0                0.400000               0.516398  NEWLINE_TOKEN:You're better off letting it sit...  2016       True     user   random  train
# 159442  698705636.0  698705636.0               -0.500000               0.971825  NEWLINE_TOKEN:::::Once again.... I'm SO glad t...  2016       True  article  blocked  train
# 159443  698709621.0  698709621.0               -0.100000               0.316228  edits, consider creating an account for yourse...  2016       True     user   random  train
# 159444  698710742.0  698710742.0                0.400000               0.516398  NEWLINE_TOKEN:That is original research, not a...  2016       True  article  blocked    dev
# 159445  698712715.0  698712715.0               -0.700000               0.948683  NEWLINE_TOKENHoly shit, you people suck. I don...  2016       True     user  blocked   test
# 159446  698713215.0  698713215.0               -0.500000               0.527046  NEWLINE_TOKEN:::::::Why are you here? Is this ...  2016       True  article  blocked    dev
# 159447  698713571.0  698713571.0                0.400000               0.516398  NEWLINE_TOKENNEWLINE_TOKEN== Danczuk ==NEWLINE...  2016       True     user   random  train
# 159448  698715087.0  698715087.0                0.900000               0.316228  NEWLINE_TOKENNEWLINE_TOKEN== Hi there ==NEWLIN...  2016       True     user   random   test
# 159449  698718403.0  698718403.0                0.600000               0.516398  `  — Preceding unsigned comment added by   •  ...  2016       True     user   random  train
# 159450  698720345.0  698720345.0                0.600000               0.516398  NEWLINE_TOKEN:You can see the discussion that ...  2016       True     user   random  train
# 159451  698731431.0  698731431.0                0.200000               0.918937  NEWLINE_TOKENNEWLINE_TOKENHaving trouble with ...  2016       True  article   random  train
# 159452  698738817.0  698738817.0               -0.500000               1.080123  NEWLINE_TOKEN::::I simply pointed out that an ...  2016       True     user  blocked   test
# 159453  698739502.0  698739502.0                0.200000               0.632456  `NEWLINE_TOKEN:::Collect, your argument here i...  2016       True  article   random  train
# 159454  698750616.0  698750616.0                0.400000               0.516398   The gang decides to spend their Friday night ...  2016       True     user   random  train
# 159455  698763771.0  698763771.0               -0.600000               0.699206  `NEWLINE_TOKENNEWLINE_TOKEN== Who do you think...  2016      False     user  blocked  train
# 159456  698773064.0  698773064.0                0.500000               0.527046   January 2016 (UTC)NEWLINE_TOKEN:::Except the ...  2016       True  article  blocked  train
# 159457  698781493.0  698781493.0                0.300000               0.674949  NEWLINE_TOKENNEWLINE_TOKEN== Tony Goldmark ==N...  2016       True     user   random  train
# 159458  698793219.0  698793219.0                0.700000               0.483046       NEWLINE_TOKEN:That was quick! Thanks, . -     2016       True     user   random  train
# 159459  698794166.0  698794166.0               -0.100000               0.316228  NEWLINE_TOKENNEWLINE_TOKEN== recent edit on gu...  2016       True     user  blocked    dev
# 159460  698794883.0  698794883.0                0.200000               0.421637  NEWLINE_TOKENNEWLINE_TOKENagree please now don...  2016       True     user  blocked  train
# ...
# 159594  699447117.0  699447117.0               -1.400000               0.699206  NEWLINE_TOKENNEWLINE_TOKENYou must be an uglyb...  2016      False     user  blocked  train
# 159595  699448424.0  699448424.0                1.100000               0.316228  NEWLINE_TOKENNEWLINE_TOKEN: Happy New Year to ...  2016       True     user   random  train
# 159596  699450992.0  699450992.0               -0.400000               0.699206  NEWLINE_TOKENNEWLINE_TOKENYou overtly undertak...  2016       True  article  blocked  train
# 159597  699456034.0  699456034.0                0.000000               0.471405  NEWLINE_TOKENNEWLINE_TOKENYou overtly undertak...  2016       True  article  blocked  train
# 159598  699456408.0  699456408.0                0.300000               0.483046  NEWLINE_TOKEN:I agree. I think his name is Hei...  2016      False  article  blocked   test
# 159599  699458324.0  699458324.0               -0.300000               0.674949  NEWLINE_TOKENNEWLINE_TOKENYou overtly undertak...  2016       True  article  blocked   test
# 159600  699474208.0  699474208.0               -0.200000               0.788811   I'm sorry but I have to go now as I am consti...  2016       True     user  blocked   test
# 159601  699480065.0  699480065.0               -0.400000               0.966092  NEWLINE_TOKENNEWLINE_TOKENI HAVE A VANDAL BOT ...  2016      False     user  blocked    dev
# 159602  699483392.0  699483392.0                0.500000               0.527046  NEWLINE_TOKENNEWLINE_TOKEN:To start: this cann...  2016       True  article   random   test
# 159603  699490271.0  699490271.0                0.400000               0.516398  NEWLINE_TOKENNEWLINE_TOKENI LOVE VIENNESE OYST...  2016      False     user  blocked    dev
# 159604  699492371.0  699492371.0                0.100000               0.567646  NEWLINE_TOKEN:::::::::::::::The magazine says ...  2016      False  article   random    dev
# 159605  699499008.0  699499008.0                0.100000               0.567646  NEWLINE_TOKENNEWLINE_TOKEN== What? ==NEWLINE_T...  2016      False     user  blocked  train
# 159606  699500374.0  699500374.0                0.200000               0.421637  NEWLINE_TOKEN::I never linked anything to Tran...  2016      False     user  blocked   test
# 159607  699501010.0  699501010.0                0.400000               0.516398  It was not written in German that way during h...  2016       True  article   random  train
# 159608  699501142.0  699501142.0                0.600000               0.516398  `NEWLINE_TOKENNEWLINE_TOKEN*Just one more comm...  2016       True  article   random    dev
# 159609  699503888.0  699503888.0                0.500000               0.707107  `NEWLINE_TOKEN::The problem is that there is n...  2016       True  article   random    dev
# 159610  699522986.0  699522986.0                0.000000               1.154701  `NEWLINE_TOKENNEWLINE_TOKEN== Dogs ==NEWLINE_T...  2016       True     user  blocked  train
# 159611  699527694.0  699527694.0                0.900000               0.316228  NEWLINE_TOKENNEWLINE_TOKEN== Edit summaries ==...  2016       True     user   random  train
# 159612  699528880.0  699528880.0               -0.100000               0.567646   Kosovo NEWLINE_TOKENNEWLINE_TOKENZoupan, dont...  2016       True  article  blocked  train
# 159613  699541441.0  699541441.0                0.200000               0.632456  `NEWLINE_TOKENNEWLINE_TOKEN== Continuit additi...  2016       True  article   random  train
# 159614  699548363.0  699548363.0                0.300000               0.483046  `::::::No personal attacks please and I have n...  2016       True     user   random  train
# 159615  699549435.0  699549435.0               -0.600000               0.966092  `NEWLINE_TOKENNEWLINE_TOKENMotherfucka the who...  2016       True     user  blocked    dev
# 159616  699554761.0  699554761.0                0.500000               0.527046  `NEWLINE_TOKENNEWLINE_TOKEN:I agree that notab...  2016       True  article   random  train
# 159617  699563903.0  699563903.0                0.400000               1.173788  NEWLINE_TOKENNEWLINE_TOKEN:: Oh, I thought you...  2016       True     user  blocked   test
# 159618  699564273.0  699564273.0                0.500000               0.527046  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKEN:: Not ...  2016       True     user  blocked  train
# 159619  699565779.0  699565779.0                0.300000               0.823273  NEWLINE_TOKENNEWLINE_TOKEN== The Rams are now ...  2016       True     user  blocked  train
# 159620  699569747.0  699569747.0               -1.200000               0.918937  `NEWLINE_TOKENNo, you utter RETARD! HISPANIC M...  2016      False  article  blocked   test
# 159621  699571336.0  699571336.0               -0.100000               0.737865  `NEWLINE_TOKENNEWLINE_TOKEN== January 2016 == ...  2016       True     user   random  train
# 159622  699571917.0  699571917.0                0.300000               0.483046  NEWLINE_TOKEN:And this is a reply, from User:A...  2016       True     user   random  train
# 159623  699578052.0  699578052.0                0.100000               0.567646  NEWLINE_TOKENNEWLINE_TOKEN== Question ==NEWLIN...  2016       True     user  blocked    dev
# 159624  699589080.0  699589080.0                0.300000               0.483046  NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENwe woul...  2016       True     user   random   test
# 159625  699589184.0  699589184.0                0.200000               0.421637  `NEWLINE_TOKENNEWLINE_TOKEN==``Denis Smith``==...  2016      False  article   random    dev
# 159626  699589797.0  699589797.0                0.500000               0.707107  `NEWLINE_TOKENNEWLINE_TOKEN== Position fields ...  2016       True     user   random  train
# 159627  699596750.0  699596750.0                0.500000               0.527046  NEWLINE_TOKEN::@ we have been over the prophet...  2016       True  article  blocked   test
# 159628  699598266.0  699598266.0                0.100000               0.994429  `NEWLINE_TOKEN::::@ so you have no sources tha...  2016       True  article  blocked  train
# 159629  699599490.0  699599490.0                0.400000               0.699206  NEWLINE_TOKEN::::::@ 16 sources say he was not...  2016       True  article  blocked  train
# 159630  699599575.0  699599575.0                0.500000               0.527046  Plus many of your 16 are non reliable self pub...  2016       True  article  blocked    dev
# 159631  699603533.0  699603533.0               -0.583333               0.792961  `NEWLINE_TOKENNEWLINE_TOKEN==``The Returds Nee...  2016      False  article  blocked  train
# 159632  699604332.0  699604332.0               -0.700000               0.674949  `GET A LIFE DHASS HOLE!== NEWLINE_TOKENFinding...  2016      False     user  blocked    dev
# 159633  699619040.0  699619040.0                0.400000               0.516398  `NEWLINE_TOKENNEWLINE_TOKEN== Name ==NEWLINE_T...  2016      False  article  blocked   test
# 159634  699619841.0  699619841.0                0.200000               0.632456  `NEWLINE_TOKEN*Support per WP:COMMONNAME. Some...  2016       True  article   random  train
# 159635  699621440.0  699621440.0                0.700000               0.483046  NEWLINE_TOKEN:True, put them in as well. I jus...  2016       True  article  blocked   test
# 159636  699621846.0  699621846.0                0.300000               0.483046  `NEWLINE_TOKENNEWLINE_TOKEN== Hebrew sources =...  2016       True  article   random  train
# 159637  699623647.0  699623647.0                0.600000               0.516398  ` (UTC)NEWLINE_TOKENNEWLINE_TOKEN==Ja-Square==...  2016       True     user   random  train
# 159638  699630687.0  699630687.0                0.600000               0.699206  `NEWLINE_TOKEN::Nothing really stood out in pa...  2016       True     user   random  train
# 159639  699640261.0  699640261.0                0.100000               0.994429   I can't even believe these accusations of har...  2016       True     user  blocked    dev
# 159640  699642939.0  699642939.0                0.000000               0.816497  , you people want me to debase myself at the h...  2016       True     user  blocked  train
# 159641  699645524.0  699645524.0               -0.800000               0.632456   Brandon Semenuk has won the event four times ...  2016       True     user  blocked    dev
# 159642  699646005.0  699646005.0               -0.200000               0.788811   Don't keep changing my page I made please. Yo...  2016       True     user  blocked  train
# 159643  699651702.0  699651702.0                0.200000               0.632456  NEWLINE_TOKENpolar bears are completely purple...  2016      False  article   random  train
# 159644  699659494.0  699659494.0               -1.000000               0.942809  im soory since when is google images not allow...  2016       True     user  blocked   test
# 159645  699660419.0  699660419.0               -1.000000               0.000000  what ever you fuggin fagNEWLINE_TOKENQuestion ...  2016       True     user  blocked  train
# 159646  699661020.0  699661020.0               -0.800000               0.632456  NEWLINE_TOKENNEWLINE_TOKEN== Nice try but no c...  2016       True     user  blocked  train
# 159647  699661834.0  699661834.0               -0.900000               0.567646  `NEWLINE_TOKENNEWLINE_TOKEN== kys ==NEWLINE_TO...  2016       True     user  blocked  train
# 159648  699663770.0  699663770.0                0.300000               0.483046  NEWLINE_TOKENNEWLINE_TOKEN== hi Drmies ==NEWLI...  2016       True     user  blocked  train
# 159649  699664687.0  699664687.0               -1.400000               0.516398   shut up mind your own business and go fuck so...  2016       True     user  blocked    dev
# 159650  699667660.0  699667660.0                0.400000               0.516398  This talk page is actually a better place to d...  2016       True  article  blocked   test
# 159651  699668748.0  699668748.0               -0.300000               0.483046  NEWLINE_TOKEN:::Yeah, it's kind of silly. Ha, ...  2016       True     user   random  train
# 159652  699673789.0  699673789.0                1.000000               0.666667  NEWLINE_TOKENNEWLINE_TOKENSelf source fom FEE ...  2016      False  article   random    dev
# 159653  699675005.0  699675005.0                0.200000               0.632456  NEWLINE_TOKEN::I've never attacked you. If you...  2016       True     user   random  train
# 159654  699683207.0  699683207.0                0.400000               0.516398  `NEWLINE_TOKENNEWLINE_TOKEN== Draft:The Beatin...  2016       True     user   random   test
# 159655  699683891.0  699683891.0                0.500000               0.527046  NEWLINE_TOKENNEWLINE_TOKEN== defunct?==NEWLINE...  2016       True  article  blocked  train
# 159656  699685538.0  699685538.0                0.600000               0.516398  NEWLINE_TOKENNEWLINE_TOKEN== International goa...  2016       True     user   random  train
# 159657  699686307.0  699686307.0                0.200000               0.421637  NEWLINE_TOKENNEWLINE_TOKEN== Proposal to Renam...  2016       True  article   random  train
# 159658  699686317.0  699686317.0                0.500000               0.849837  NEWLINE_TOKENNEWLINE_TOKENInteresting. In your...  2016       True  article   random    dev
# 159659  699688359.0  699688359.0                0.111111               0.781736  NEWLINE_TOKENNEWLINE_TOKEN== These are the fil...  2016      False     user   random   test
# 159660  699692272.0  699692272.0                0.200000               0.421637  , PANEWLINE_TOKEN| Mitch Fraas NEWLINE_TOKENNE...  2016       True     user   random  train
# 159661  699698850.0  699698850.0                0.800000               0.421637  NEWLINE_TOKENNEWLINE_TOKENYeah, I realized I c...  2016       True     user  blocked   test
# 159662  699702006.0  699702006.0                0.400000               0.516398  NEWLINE_TOKEN:There's some weaseling and pov p...  2016       True  article  blocked  train
# 159663  699703322.0  699703322.0                0.000000               0.816497  `NEWLINE_TOKEN:::Yeah and in the earlier sente...  2016       True  article  blocked  train
# 159664  699715740.0  699715740.0                0.300000               0.483046  `NEWLINE_TOKEN:::::::::::::Again, WP:NOTAFORUM...  2016       True  article  blocked  train
# 159665  699717990.0  699717990.0                0.100000               0.316228  NEWLINE_TOKENNEWLINE_TOKEN== Where are you? ==...  2016       True     user   random  train
# 159666  699730832.0  699730832.0                0.200000               0.421637  NEWLINE_TOKENNEWLINE_TOKEN== Japanese Scene ==...  2016      False  article  blocked  train
# 159667  699741197.0  699741197.0                0.400000               0.699206  `NEWLINE_TOKENNEWLINE_TOKEN== Jim1138 ==NEWLIN...  2016       True     user  blocked  train
# 159668  699753082.0  699753082.0                0.200000               0.632456  NEWLINE_TOKENNEWLINE_TOKEN== Why oh why... ==N...  2016       True     user  blocked  train
# 159669  699755057.0  699755057.0                0.727273               0.467099  NEWLINE_TOKENNEWLINE_TOKEN== Daily Beast Artic...  2016       True  article  blocked  train
# 159670  699756053.0  699756053.0                0.300000               0.674949  `The lead also lacks proper citation and sourc...  2016       True  article  blocked  train
# 159671  699756185.0  699756185.0                0.300000               0.483046  `NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENThe le...  2016       True  article  blocked  train
# 159672  699760682.0  699760682.0               -0.300000               0.674949  NEWLINE_TOKEN:::::long story short. He thinks ...  2016       True     user   random  train
# 159673  699763518.0  699763518.0                0.700000               0.483046  `NEWLINE_TOKENNEWLINE_TOKEN==:List of St. Loui...  2016       True     user   random  train
# 159674  699780538.0  699780538.0                0.700000               0.674949          NEWLINE_TOKEN:::::: Well done, thanks!     2016      False     user  blocked  train
# 159675  699803377.0  699803377.0                0.900000               0.567646  `NEWLINE_TOKENNEWLINE_TOKEN== Page patrolled =...  2016       True     user   random  train
# 159676  699813325.0  699813325.0                0.000000               0.666667  `NEWLINE_TOKEN::I'm talking about you making u...  2016       True  article  blocked    dev
# 159677  699820699.0  699820699.0                0.300000               0.483046  `NEWLINE_TOKENYes, from the word ``Guci`` or `...  2016       True     user  blocked   test
# 159678  699822249.0  699822249.0                0.100000               0.994429  `NEWLINE_TOKENNEWLINE_TOKEN:``Comment````. Gen...  2016       True  article  blocked  train
# 159679  699826615.0  699826615.0                0.600000               0.699206  NEWLINE_TOKEN*Support and recommend moving thi...  2016       True  article   random  train
# 159680  699843603.0  699843603.0                0.800000               0.632456  `NEWLINE_TOKENNEWLINE_TOKEN== File:Romantic Wa...  2016       True     user   random  train
# 159681  699848324.0  699848324.0                0.400000               0.516398  `NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENThese ...  2016       True  article  blocked  train
# 159682  699851288.0  699851288.0                0.400000               0.516398  NEWLINE_TOKENNEWLINE_TOKENThe Institute for Hi...  2016       True  article  blocked   test
# 159683  699857133.0  699857133.0                0.500000               0.527046  NEWLINE_TOKEN:The way you're trying to describ...  2016       True  article  blocked    dev
# 159684  699891012.0  699891012.0               -0.100000               1.100505  NEWLINE_TOKENNEWLINE_TOKEN== Warning ==NEWLINE...  2016       True     user  blocked  train
# 159685  699897151.0  699897151.0                0.400000               0.516398  Alternate option===NEWLINE_TOKENIs there perha...  2016       True  article  blocked   test
#
# [159686 rows x 10 columns]

# %% [markdown]
# ## functions and classes

# %%
class standardize_text():
    def __init__(self):
        return
    
    def replace_entities(self, col):
        col = col.replace(r'\[WIKI_LINK\:\s[^\]]+\]', 'wikilink', regex=True)
        col = col.replace(r'\[EXTERNA_LINK\:\s[^\]]+\]', 'externalink', regex=True)
        col = col.replace(r'(https?\:\/\/|www)[^\s]+wikipedia[^\s]+', 'wikilink', regex=True)
        col = col.replace(r'(https?\:\/\/|www)[^\s]+[^wikipedia][^\s]+', 'externalink', regex=True)
        
        return col
    
    def clean(self, col):
        col = col.str.lower()
        col = col.replace(r'\n', ' ').replace(r'\t', ' ')
        col = col.replace(r'[^a-z\s]', '', regex=True)
        col = col.replace(r'\s+', ' ', regex=True)
        col = col.replace(r"([a-z]+?)\1+", r"\1\1", regex=True) # removes any repetitions of letters more than twice
        col = col.replace(r"\b(\w+)(\s)(\1\2?)+", r"\1", regex=True) # removes any repetitions of words more than once
        col = col.str.strip()
        
        return col

# %%
class create_count_features(BaseEstimator):
    def __init__(self):
        with open("../../External Data/badwords.txt") as f:
            badwords = [l.strip() for l in f.readlines()]
        self.badwords_ = badwords
        
    def fit(self, documents, y=None):
        return self

    def transform(self, documents):
        ## some handcrafted features!
        n_words = [len(c.split()) for c in documents]
        n_chars = [len(c) for c in documents]
        # number of uppercase words
        allcaps = [np.sum([w.isupper() for w in comment.split()])
               for comment in documents]
        # longest word
        max_word_len = [np.max([len(w) for w in c.split()]) for c in documents]
        # average word length
        mean_word_len = [np.mean([len(w) for w in c.split()])
                                            for c in documents]
        # number of google badwords:
        n_bad = [np.sum([c.lower().count(w) for w in self.badwords_])
                                                for c in documents]
        exclamation = [c.count("!") for c in documents]
        question = [c.count("?") for c in documents]
        newlines = [c.count("\n") for c in documents]
        tabs = [c.count("\t") for c in documents]
        wikilink = [c.count("wikilink") for c in documents]
        extralink = [c.count("externalink") for c in documents]
        spaces = [c.count(" ") for c in documents]

        allcaps_ratio = np.array(allcaps) / np.array(n_words, dtype=np.float)
        bad_ratio = np.array(n_bad) / np.array(n_words, dtype=np.float)

        return np.array([n_words, 
                         n_chars, 
                         allcaps, 
                         max_word_len,
                         mean_word_len, 
                         exclamation, 
                         question, 
                         tabs,
                         newlines,
                         wikilink, 
                         extralink, 
                         spaces, 
                         bad_ratio, 
                         n_bad, 
                         allcaps_ratio]).T
    
    def get_feature_names(self):
        return ['n_words', 
                 'n_chars', 
                 'allcaps', 
                 'max_word_len',
                 'mean_word_len', 
                 'exclamation', 
                 'question', 
                 'tabs',
                 'newlines',
                 'wikilink', 
                 'extralink', 
                 'spaces', 
                 'bad_ratio', 
                 'n_bad', 
                 'allcaps_ratio']

# %%
def train_best_model(pipe, parameters, X_train, y_train, X_val, y_val):
    predictions = pd.DataFrame()
    models = {}
    loss = 0
    for toxicity in classes:
        print(toxicity)
        est = GridSearchCV(pipe, 
                           parameters, 
                           scoring='neg_log_loss', 
                           n_jobs=-1,
                           cv=3, 
                           verbose=1)
        est.fit(X_train, y_train[toxicity])
        print(est.best_params_)
        print(est.best_score_)
        
        predictions[toxicity] = est.best_estimator_.predict_proba(X_val)[:, 1]
        models[toxicity] = est.best_estimator_
        
        ll = log_loss(y_val[toxicity], predictions[toxicity])
        print('>>> test log-loss: %s' % str(ll.round(3)))
        loss = loss + ll
        
    print('DONE! test mean log-loss: %s' % str(loss/6.))
    return predictions, models

# %% [markdown]
# ## prepping features

# %%
st = standardize_text()

# %%
train['comment_text_clean'] = st.clean(st.replace_entities(train['comment_text']))
test['comment_text_clean'] = st.clean(st.replace_entities(test['comment_text']))

# %%
rs = ShuffleSplit(n_splits=1, test_size=0.2)

# %%
for j, k in rs.split(train):
    train_index = j
    val_index = k

# %%
X_train_df = train.loc[train_index, 'comment_text_clean'] 
X_val_df = train.loc[val_index, 'comment_text_clean']
y_train = train.loc[train_index, classes]
y_val = train.loc[val_index, classes]

# %%
X_train_cnt = st.replace_entities(train.loc[train_index, 'comment_text']) 
X_val_cnt = st.replace_entities(train.loc[val_index, 'comment_text'])
X_test_cnt = st.replace_entities(test.loc[:, 'comment_text'])

# %%
cnt_feat = create_count_features()
temp = pd.DataFrame(cnt_feat.transform(X_test_cnt), columns=cnt_feat.get_feature_names())

# %%
temp.mean()
# Out:
# n_words           69.547657
# n_chars          418.093838
# allcaps            2.333831
# max_word_len      14.171812
# mean_word_len      5.662057
# exclamation        1.086952
# question           0.309875
# tabs               0.017731
# newlines           1.624988
# wikilink           1.386426
# extralink          0.067719
# spaces            68.632217
# bad_ratio          0.010784
# n_bad              0.642076
# allcaps_ratio      0.036950
# dtype: float64

# %% [markdown]
# ### count based model

# %%
# %%time
cnt_feat = create_count_features()
scaler = MinMaxScaler()
clf = RandomForestClassifier(n_estimators=200, class_weight=None, n_jobs=-1, bootstrap=True)  

pipe = Pipeline(steps=[('cnt', cnt_feat),
                       ('scaler', scaler), 
                       ('clf', clf)])

parameters = {'clf__max_depth':[5, 10],
              'clf__max_features': [3, 5, 10]}

cnt_predictions, cnt_models = train_best_model(pipe, parameters, X_train_cnt, y_train, X_val_cnt, y_val)
# Out:
# toxic
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed: 10.7min finished
# {'clf__max_depth': 10, 'clf__max_features': 5}
# -0.199992499049
# >>> test log-loss: 0.194
# severe_toxic
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed: 10.9min finished
# {'clf__max_depth': 10, 'clf__max_features': 3}
# -0.0283502357952
# >>> test log-loss: 0.028
# obscene
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed: 11.7min finished
# {'clf__max_depth': 10, 'clf__max_features': 5}
# -0.0959254347452
# >>> test log-loss: 0.096
# threat
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed: 10.7min finished
# {'clf__max_depth': 10, 'clf__max_features': 3}
# -0.0176145394103
# >>> test log-loss: 0.015
# insult
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed: 11.2min finished
# {'clf__max_depth': 10, 'clf__max_features': 5}
# -0.116962253393
# >>> test log-loss: 0.116
# identity_hate
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed: 11.3min finished
# {'clf__max_depth': 10, 'clf__max_features': 3}
# -0.0353031382521
# >>> test log-loss: 0.036
# DONE! test mean log-loss: 0.0807707119629
# CPU times: user 7min 59s, sys: 5.35 s, total: 8min 5s
# Wall time: 1h 12min 31s

# %%
joblib.dump(cnt_models, datetime.now().strftime('%Y%m%d%H%M')+'_cnt_models.pkl')
# Out:
# ['201801021402_cnt_models.pkl']

# %% [markdown]
# ### word level model

# %%
# %%time
selec = SelectPercentile(chi2, percentile=20)
clf = LogisticRegression(C=5.0, class_weight=None, n_jobs=1)  
vect_words = TfidfVectorizer(max_features=None,
                             lowercase=False,
                             analyzer='word', 
                             ngram_range=(1, 3), 
                             max_df=0.1, 
                             min_df=3,
                             stop_words='english',
                             use_idf=True)

pipe = Pipeline(steps=[('vect', vect_words),
                       ('selec', selec), 
                       ('clf', clf)])

parameters = {'vect__ngram_range': [(1,1), (1,2)],
              'selec__percentile':[5, 10, 20], 
              'clf__C':[5, 10, 20]}

wd_predictions, wd_models = train_best_model(pipe, parameters, X_train_df, y_train, X_val_df, y_val)
# Out:
# toxic
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done  54 out of  54 | elapsed:  3.8min finished
# {'clf__C': 10, 'selec__percentile': 20, 'vect__ngram_range': (1, 1)}
# -0.121924871403
# >>> test log-loss: 0.115
# severe_toxic
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done  54 out of  54 | elapsed:  3.9min finished
# {'clf__C': 5, 'selec__percentile': 10, 'vect__ngram_range': (1, 1)}
# -0.0288962926679
# >>> test log-loss: 0.028
# obscene
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done  54 out of  54 | elapsed:  3.8min finished
# {'clf__C': 10, 'selec__percentile': 5, 'vect__ngram_range': (1, 1)}
# -0.0650090594645
# >>> test log-loss: 0.061
# threat
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done  54 out of  54 | elapsed:  3.8min finished
# {'clf__C': 10, 'selec__percentile': 5, 'vect__ngram_range': (1, 1)}
# -0.0117985050672
# >>> test log-loss: 0.01
# insult
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done  54 out of  54 | elapsed:  3.8min finished
# {'clf__C': 5, 'selec__percentile': 20, 'vect__ngram_range': (1, 1)}
# -0.0842258663394
# >>> test log-loss: 0.08
# identity_hate
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done  54 out of  54 | elapsed:  3.7min finished
# {'clf__C': 5, 'selec__percentile': 10, 'vect__ngram_range': (1, 1)}
# -0.027185635327
# >>> test log-loss: 0.027
# DONE! test mean log-loss: 0.0536270852381
# CPU times: user 48.9 s, sys: 8.73 s, total: 57.6 s
# Wall time: 23min 16s

# %%
joblib.dump(cnt_models, datetime.now().strftime('%Y%m%d%H%M')+'_wd_models.pkl')
# Out:
# ['201801021407_wd_models.pkl']

# %% [markdown]
# ### char level model

# %%
# %%time
selec = SelectPercentile(chi2, percentile=20)
clf = LogisticRegression(C=5.0, class_weight=None, n_jobs=1)  
vect_words = TfidfVectorizer(max_features=None,
                             lowercase=False,
                             analyzer='char', 
                             ngram_range=(1, 5), 
                             max_df=0.1, 
                             min_df=3,
                             stop_words='english',
                             use_idf=True)

pipe = Pipeline(steps=[('vect', vect_words),
                       ('selec', selec), 
                       ('clf', clf)])

parameters = {'vect__ngram_range': [(1, 5), (2,4)],
              'selec__percentile':[1, 5, 10], 
              'clf__C':[1, 10, 20]}

char_predictions, char_models = train_best_model(pipe, parameters, X_train_df, y_train, X_val_df, y_val)
# Out:
# toxic
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed: 28.3min
# [Parallel(n_jobs=-1)]: Done  81 out of  81 | elapsed: 52.5min finished
# {'clf__C': 15, 'selec__percentile': 5, 'vect__ngram_range': (1, 5)}
# -0.108849825167
# >>> test log-loss: 0.101
# severe_toxic
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed: 29.2min
# [Parallel(n_jobs=-1)]: Done  81 out of  81 | elapsed: 53.2min finished
# {'clf__C': 5, 'selec__percentile': 10, 'vect__ngram_range': (2, 4)}
# -0.0267918954029
# >>> test log-loss: 0.027
# obscene
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed: 28.9min
# [Parallel(n_jobs=-1)]: Done  81 out of  81 | elapsed: 52.7min finished
# {'clf__C': 15, 'selec__percentile': 5, 'vect__ngram_range': (1, 5)}
# -0.058170838787
# >>> test log-loss: 0.056
# threat
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed: 29.1min
# [Parallel(n_jobs=-1)]: Done  81 out of  81 | elapsed: 53.1min finished
# {'clf__C': 15, 'selec__percentile': 5, 'vect__ngram_range': (2, 4)}
# -0.0107006483618
# >>> test log-loss: 0.009
# insult
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed: 29.0min
# [Parallel(n_jobs=-1)]: Done  81 out of  81 | elapsed: 52.9min finished
# {'clf__C': 10, 'selec__percentile': 5, 'vect__ngram_range': (1, 5)}
# -0.0758156213287
# >>> test log-loss: 0.072
# identity_hate
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed: 28.9min
# [Parallel(n_jobs=-1)]: Done  81 out of  81 | elapsed: 52.7min finished
# {'clf__C': 10, 'selec__percentile': 10, 'vect__ngram_range': (2, 4)}
# -0.0248541566799
# >>> test log-loss: 0.024
# DONE! test mean log-loss: 0.0483288061892
# CPU times: user 7min 28s, sys: 21.5 s, total: 7min 49s
# Wall time: 5h 23min 48s

# %%
joblib.dump(cnt_models, datetime.now().strftime('%Y%m%d%H%M')+'_char_models.pkl')
# Out:
# ['201801021408_char_models.pkl']

# %% [markdown]
# ## stacking all models

# %%
pred_list = [wd_predictions, char_predictions, cnt_predictions]

# %%
# %%time
X_train_stack = np.column_stack([x.values for x in pred_list])

clf = RandomForestClassifier(n_estimators=1000, 
                             class_weight=None, 
                             n_jobs=-1, 
                             bootstrap=True,
                             max_depth=30,
                             max_features=4)  

clf.fit(X_train_stack, y_val)

predictions = clf.predict_proba(X_train_stack)

print(log_loss(y_val, np.column_stack([x[:,1] for x in predictions])))
# Out:
# 0.221332941206
# CPU times: user 3min 36s, sys: 880 ms, total: 3min 37s
# Wall time: 56 s

# %% [markdown]
# ## exploration of the results

# %%
df = pd.DataFrame(X_val_df.reset_index(drop=True))
df['label'] = y_val['toxic'].reset_index(drop=True)
df['pred'] = np.column_stack([x[:,1] for x in predictions])[:,0]

# %%
def generate_cloud(col):
    text = '.. '.join(list(col))
    wordcloud = WordCloud(max_font_size=40).generate(text)
    plt.figure(figsize=(15,7))
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
generate_cloud(df[(df.label==1) & (df.pred>0.5)].comment_text_clean)

# %%
df[df.comment_text_clean.str.contains('hate u')]
# Out:
#                                       comment_text_clean  label  pred
# 10196  sirmaam thank you for the heads up about needi...      0   0.0

# %%
confusion_matrix(df.label, (df.pred>0.5))
# Out:
# array([[17351,     0],
#        [    0,  1820]])

# %%
df[(df.label==0) & (df.pred>0.5)].comment_text_clean
# Out:
# Series([], Name: comment_text_clean, dtype: object)

# %%
train[train.comment_text.str.contains('I promise you')]['comment_text']
# Out:
# 23269    The solution without a reference \n\n  //  Y1+...
# 24603    I'm not prepared for you, I promise you 13 of ...
# 25627    "\n\nThis ""DavidShankBone"" has been personal...
# 36554    I only got blocked for spamming. I promise you...
# 38777    For now, I have lost. But I will come back wit...
# 53689    Legitimacy\n\nTo me, it has been an honor to b...
# 55133    Thank You So Much! \n\nToday, I thought I woul...
# 55336    I promise you the first thing I will do is hav...
# 57558    You're gonna pay for what you've done, Gregory...
# 63773    No information in any article was being based ...
# 66330    Your hobbies... \n\nMum's the word, I won't sa...
# 79413    "\n\n Editor review \n\nHey Nish, I'm currentl...
# 86899    "\n\n Please \nI promise you in not a BBHS. Pl...
# Name: comment_text, dtype: object

# %% [markdown]
# # predictions on the test set

# %%
models_list = [(wd_models, test['comment_text_clean']), 
               (char_models, test['comment_text_clean']), 
               (cnt_models, X_test_cnt)]

# %%
# %%time
all_results = []
for j, x in enumerate(models_list):
    print(j)
    for tox in classes:
        print('     '+tox)
        all_results.append(x[0][tox].predict_proba(x[1])[:,1])
# Out:
# 0
#      toxic
#      severe_toxic
#      obscene
#      threat
#      insult
#      identity_hate
# 1
#      toxic
#      severe_toxic
#      obscene
#      threat
#      insult
#      identity_hate
# 2
#      toxic
#      severe_toxic
#      obscene
#      threat
#      insult
#      identity_hate
# CPU times: user 30min 56s, sys: 8.83 s, total: 31min 5s
# Wall time: 30min 41s

# %%
# %%time
X_train_stack = np.column_stack(all_results)
# Out:
# CPU times: user 72 ms, sys: 0 ns, total: 72 ms
# Wall time: 73.3 ms

# %%
predictions = clf.predict_proba(X_train_stack)
predictions = pd.DataFrame(np.column_stack([x[:,1] for x in predictions]), columns=classes)
predictions['id'] = test.id

# %%
predictions.to_csv(datetime.now().strftime('%Y%m%d%H%M')+'_submission.csv', index=False)
